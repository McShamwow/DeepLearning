# %%
from fastai.vision.all import *

# %%
#!kaggle datasets download -d kritikseth/fruit-and-vegetable-image-recognition

# %%
vegetables = DataBlock(
     blocks = (ImageBlock, CategoryBlock),
     get_items = get_image_files,
     splitter = RandomSplitter(valid_pct=0.2, seed=42),
     get_y = parent_label,
     item_tfms = Resize(128)
)

path = Path('D:/Jupyter Notebook/vegetables') 
get_image_files(path)
# Out:
# (#189) [Path('D:/Jupyter Notebook/vegetables/cabbage/Image_1.jpg'),Path('D:/Jupyter Notebook/vegetables/cabbage/Image_10.jpg'),Path('D:/Jupyter Notebook/vegetables/cabbage/Image_100.jpg'),Path('D:/Jupyter Notebook/vegetables/cabbage/Image_11.jpg'),Path('D:/Jupyter Notebook/vegetables/cabbage/Image_12.jpg'),Path('D:/Jupyter Notebook/vegetables/cabbage/Image_13.jpg'),Path('D:/Jupyter Notebook/vegetables/cabbage/Image_14.jpg'),Path('D:/Jupyter Notebook/vegetables/cabbage/Image_15.jpg'),Path('D:/Jupyter Notebook/vegetables/cabbage/Image_16.jpg'),Path('D:/Jupyter Notebook/vegetables/cabbage/Image_17.jpg')...]

# %%
dls = vegetables.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
vegetables = vegetables.new(
     item_tfms=RandomResizedCrop(224, min_scale=0.5),
     batch_tfms=aug_transforms()
)

learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(8)
# Out:
# C:\Users\User\anaconda3\envs\py37_fastai\lib\site-packages\fastai\vision\learner.py:288: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# C:\Users\User\anaconda3\envs\py37_fastai\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
#!kaggle datasets download -d utkarshsaxenadn/fast-food-classification-dataset
# Out:
# ...
#   0%|          | 0.00/821M [00:00<?, ?B/s]
#   0%|          | 1.00M/821M [00:00<04:20, 3.30MB/s]
#   0%|          | 2.00M/821M [00:00<02:45, 5.17MB/s]
#   1%|          | 5.00M/821M [00:00<01:14, 11.5MB/s]
#   1%|          | 7.00M/821M [00:00<01:09, 12.3MB/s]
#   1%|1         | 9.00M/821M [00:00<01:00, 14.0MB/s]
#   2%|1         | 14.0M/821M [00:00<00:39, 21.4MB/s]
#   2%|2         | 17.0M/821M [00:01<00:36, 22.8MB/s]
#   2%|2         | 20.0M/821M [00:01<00:35, 23.6MB/s]
#   3%|2         | 23.0M/821M [00:01<00:32, 25.6MB/s]
#   3%|3         | 26.0M/821M [00:01<00:31, 26.5MB/s]
#   4%|3         | 29.0M/821M [00:01<00:30, 26.8MB/s]
#   4%|3         | 32.0M/821M [00:01<00:35, 23.3MB/s]
#   4%|4         | 35.0M/821M [00:01<00:37, 22.0MB/s]
#   5%|4         | 38.0M/821M [00:02<00:38, 21.2MB/s]
#   5%|4         | 41.0M/821M [00:02<00:49, 16.4MB/s]
#   6%|5         | 46.0M/821M [00:02<00:35, 22.9MB/s]
#   6%|5         | 49.0M/821M [00:02<00:33, 24.0MB/s]
# ...

# %%
entrees = DataBlock(
     blocks = (ImageBlock, CategoryBlock),
     get_items = get_image_files,
     splitter = RandomSplitter(valid_pct=0.1, seed=42),
     get_y = parent_label,
     item_tfms = Resize(128)
)

path = Path('D:/Jupyter Notebook/fast_food') 
get_image_files(path)
# Out:
# (#400) [Path('D:/Jupyter Notebook/fast_food/Burger/Burger-Test (1).jpeg'),Path('D:/Jupyter Notebook/fast_food/Burger/Burger-Test (10).jpeg'),Path('D:/Jupyter Notebook/fast_food/Burger/Burger-Test (100).jpeg'),Path('D:/Jupyter Notebook/fast_food/Burger/Burger-Test (101).jpeg'),Path('D:/Jupyter Notebook/fast_food/Burger/Burger-Test (102).jpeg'),Path('D:/Jupyter Notebook/fast_food/Burger/Burger-Test (103).jpeg'),Path('D:/Jupyter Notebook/fast_food/Burger/Burger-Test (104).jpeg'),Path('D:/Jupyter Notebook/fast_food/Burger/Burger-Test (105).jpeg'),Path('D:/Jupyter Notebook/fast_food/Burger/Burger-Test (106).jpeg'),Path('D:/Jupyter Notebook/fast_food/Burger/Burger-Test (107).jpeg')...]

# %%
dls = entrees.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
entrees = entrees.new(
     item_tfms=RandomResizedCrop(224, min_scale=0.5),
     batch_tfms=aug_transforms()
)

learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(8)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.023980</td>
#       <td>1.806146</td>
#       <td>0.450000</td>
#       <td>00:01</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
#!kaggle datasets download -d preetviradiya/brian-tumor-dataset
# Out:
# ...
#   0%|          | 0.00/107M [00:00<?, ?B/s]
#   1%|          | 1.00M/107M [00:00<00:32, 3.42MB/s]
#   2%|1         | 2.00M/107M [00:00<00:26, 4.09MB/s]
#   3%|2         | 3.00M/107M [00:00<00:19, 5.62MB/s]
#   4%|3         | 4.00M/107M [00:00<00:18, 5.99MB/s]
#   5%|4         | 5.00M/107M [00:00<00:16, 6.33MB/s]
#   6%|5         | 6.00M/107M [00:01<00:16, 6.46MB/s]
#   7%|6         | 7.00M/107M [00:01<00:14, 7.15MB/s]
#   7%|7         | 8.00M/107M [00:01<00:13, 7.59MB/s]
#   8%|8         | 9.00M/107M [00:01<00:13, 7.90MB/s]
#   9%|9         | 10.0M/107M [00:01<00:12, 8.17MB/s]
#  10%|#         | 11.0M/107M [00:01<00:11, 8.46MB/s]
#  11%|#1        | 12.0M/107M [00:01<00:11, 8.97MB/s]
#  13%|#3        | 14.0M/107M [00:01<00:10, 9.60MB/s]
#  14%|#3        | 15.0M/107M [00:02<00:09, 9.72MB/s]
#  16%|#5        | 17.0M/107M [00:02<00:10, 9.27MB/s]
#  17%|#6        | 18.0M/107M [00:02<00:10, 8.90MB/s]
#  19%|#8        | 20.0M/107M [00:02<00:08, 10.2MB/s]
# ...

# %%
brain_tumors = DataBlock(
     blocks = (ImageBlock, CategoryBlock),
     get_items = get_image_files,
     splitter = RandomSplitter(valid_pct=0.3, seed=42),
     get_y = parent_label,
     item_tfms = Resize(128)
)

path = Path('D:/Jupyter Notebook/Brain Tumor Data Set') 
get_image_files(path)
# Out:
# (#200) [Path('D:/Jupyter Notebook/Brain Tumor Data Set/Brain Tumor/Cancer (1).jpg'),Path('D:/Jupyter Notebook/Brain Tumor Data Set/Brain Tumor/Cancer (10).jpg'),Path('D:/Jupyter Notebook/Brain Tumor Data Set/Brain Tumor/Cancer (100).jpg'),Path('D:/Jupyter Notebook/Brain Tumor Data Set/Brain Tumor/Cancer (11).jpg'),Path('D:/Jupyter Notebook/Brain Tumor Data Set/Brain Tumor/Cancer (12).jpg'),Path('D:/Jupyter Notebook/Brain Tumor Data Set/Brain Tumor/Cancer (13).jpg'),Path('D:/Jupyter Notebook/Brain Tumor Data Set/Brain Tumor/Cancer (14).jpg'),Path('D:/Jupyter Notebook/Brain Tumor Data Set/Brain Tumor/Cancer (15).jpg'),Path('D:/Jupyter Notebook/Brain Tumor Data Set/Brain Tumor/Cancer (16).jpg'),Path('D:/Jupyter Notebook/Brain Tumor Data Set/Brain Tumor/Cancer (17).jpg')...]

# %%
dls = brain_tumors.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
brain_tumors = brain_tumors.new(
     item_tfms=RandomResizedCrop(224, min_scale=0.5),
     batch_tfms=aug_transforms()
)

learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(16)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.328923</td>
#       <td>1.608464</td>
#       <td>0.416667</td>
#       <td>00:01</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...
